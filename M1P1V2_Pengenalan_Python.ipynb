# %% [markdown]
# Nama : Nikmatun Khasanah (1915015027)

# %% [markdown]
# PENGENALAN PYTHON

# %% [markdown]
# Python adalah bahasa pemrograman tingkat tinggi dengan dynamic semantics, bersifat object oriented dan imterpretatif.
# Penjelasan:
# 1.  Bahasa pemrograman tingkat tinggi artinya sintaks kode lebih mudah ditafsirkan oleh manusia.
# 2. Object oriented artinya bahasa pemrograman ini berorientasi pada objek.
# 3. Dynamic semantics artinya python secara otomatis akan menyesuaikan tipe dari suatu variabel berdasarkan inputnya.

# %% [markdown]
# MENGAPA PYTHON?

# %% [markdown]
# 1. Mudah dipahami
# 2. Gratis dan open source
# 3. Dinamis
# 4. Memiliki library terlengkap untuk data sains

# %% [markdown]
# STRUKTUR PROGRAM PADA PYTHON

# %% [markdown]
# 1. Statements

# %%
print ("Belajar python sangat menyenangkan")
print ("hallo cantik, semangat yukk")
# Out:
# Belajar python sangat menyenangkan
# hallo cantik, semangat yukk

# %% [markdown]
# 2. Variables

# %%
bilangan1 = 5
bilangan2 = 10
kalimat = "Pejuang data 3"

# %% [markdown]
# 3. Literals yaitu simbol-simbol yang kita gunakan untuk mengisi suatu variabel

# %% [markdown]
# 4. Operators yaitu simbol-simbol yang kita gunakan untuk mengubah nilai dari satu variabel atau lebih variabel dan literal

# %%
bilangan1+bilangan2
# Out:
# 15

# %% [markdown]
# 5. Reserved words yaitu kumpulan kata-kata yang memiliki makna khusus dalam bahasa pemrograman python. Kata false, return, dan for merupakan contohnya

# %% [markdown]
# 6. Whitespace, dalam bahasa python spasi dan tab memiliki makna khusus untuk menandai serangkaian blok dalam kode python

# %% [markdown]
# 7. Comments merupakan sekumpulan teks yang dituliskan didalam sebuah program yang tidak akan mempengaruhi hasil dari sebuah program. Terdapat 2 jenis comment didalam python yaitu:

# %% [markdown]
#       a. single line comment (comment dalam satu baris)

# %%
print ("Belajar python YUKK")
# Out:
# Belajar python YUKK

# %% [markdown]
#         b. multi line comment (comment dalam beberapa baris)

# %%
'''
Panjang pada sell kode python 
Misalnya dokumentasi program, spesifikasi input, output dan sebagainya
'''
print ("Belajar python sangat menyenangkan")
# Out:
# Belajar python sangat menyenangkan
